# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv('D:\datasets to publish\LaLiga Matches Dataset (2019-2025, FBref)\matches_full.csv')
df
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 0              0  2024-08-17  21:30  La Liga   Matchweek 1  Sat  Away      W
# 1              1  2024-08-24  19:00  La Liga   Matchweek 2  Sat  Home      W
# 2              2  2024-08-27  21:30  La Liga   Matchweek 3  Tue  Away      W
# 3              3  2024-08-31  17:00  La Liga   Matchweek 4  Sat  Home      W
# 4              4  2024-09-15  16:15  La Liga   Matchweek 5  Sun  Away      W
# ...          ...         ...    ...      ...           ...  ...   ...    ...
# 4313          48  2020-07-05  17:00  La Liga  Matchweek 34  Sun  Home      L
# 4314          49  2020-07-08  22:00  La Liga  Matchweek 35  Wed  Away      L
# 4315          50  2020-07-12  14:00  La Liga  Matchweek 36  Sun  Home      L
# 4316          51  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L
# 4317          52  2020-07-19  21:00  La Liga  Matchweek 38  Sun  Home      D
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# date                0
# time                0
# comp                0
# round               0
# day                 0
# venue               0
# result              0
# gf                  0
# ga                  0
# opponent            0
# xg                  0
# xga                 0
# poss                0
# attendance        974
# captain             0
# formation           0
# opp formation       0
# referee            54
# match report        0
# notes            4318
# sh                  0
# sot                 0
# dist                3
# fk                  0
# pk                  0
# pkatt               0
# season              0
# team                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['team'].value_counts()
# Out:
# team
# Barcelona          216
# Atletico Madrid    216
# Real Madrid        216
# Athletic Club      216
# Real Betis         216
# Celta Vigo         216
# Real Sociedad      216
# Osasuna            216
# Valencia           216
# Getafe             216
# Sevilla            216
# Villarreal         215
# Mallorca           178
# Alaves             178
# Granada            152
# Cadiz              152
# Rayo Vallecano     140
# Valladolid         140
# Espanyol           139
# Levante            114
# Elche              114
# Girona             102
# Almeria             76
# Eibar               76
# Las Palmas          64
# Leganes             64
# Huesca              38
# Name: count, dtype: int64

# %%
df.drop(columns=['notes','Unnamed: 0'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance       974
# captain            0
# formation          0
# opp formation      0
# referee           54
# match report       0
# sh                 0
# sot                0
# dist               3
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4318 entries, 0 to 4317
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4318 non-null   object
#  1   time           4318 non-null   object
#  2   comp           4318 non-null   object
#  3   round          4318 non-null   object
#  4   day            4318 non-null   object
#  5   venue          4318 non-null   object
#  6   result         4318 non-null   object
#  7   gf             4318 non-null   float64
#  8   ga             4318 non-null   float64
#  9   opponent       4318 non-null   object
#  10  xg             4318 non-null   float64
#  11  xga            4318 non-null   float64
#  12  poss           4318 non-null   float64
#  13  attendance     3344 non-null   float64
#  14  captain        4318 non-null   object
#  15  formation      4318 non-null   object
#  16  opp formation  4318 non-null   object
# ...

# %%
df.describe()
# Out:
#                 gf           ga           xg          xga         poss  \
# count  4318.000000  4318.000000  4318.000000  4318.000000  4318.000000
# mean      1.270032     1.270032     1.262112     1.262112    50.001158
# std       1.168970     1.168970     0.774208     0.774208    11.435318
# min       0.000000     0.000000     0.000000     0.000000    18.000000
# 25%       0.000000     0.000000     0.700000     0.700000    42.000000
# 50%       1.000000     1.000000     1.100000     1.100000    50.000000
# 75%       2.000000     2.000000     1.700000     1.700000    58.000000
# max       7.000000     7.000000     5.900000     5.900000    82.000000
#
#          attendance           sh          sot         dist           fk  \
# count   3344.000000  4318.000000  4318.000000  4315.000000  4318.000000
# mean   27864.883373    11.512043     3.785086    18.184774     0.453219
# std    18103.653603     4.838242     2.288167     3.413213     0.697135
# ...

# %%
att_mode = df['attendance'].mean()
df['attendance'] = df['attendance'].fillna(att_mode)

# %%
ref_mode = df['referee'].mode()
df['referee'] = df['referee'].fillna(ref_mode [0])

# %%
dist_mean = df['dist'].mean()
df['dist'] = df['dist'].fillna(dist_mean)

# %%
for i in df['comp'] :
    if i == 'La Liga':
        df['comp'] = df['comp'].replace(i,1)
print(df['comp'].value_counts())
# Out:
# comp
# 1    4318
# Name: count, dtype: int64

# %%
df
# Out:
#             date   time  comp         round  day venue result   gf   ga  \
# 0     2024-08-17  21:30     1   Matchweek 1  Sat  Away      W  2.0  1.0
# 1     2024-08-24  19:00     1   Matchweek 2  Sat  Home      W  2.0  1.0
# 2     2024-08-27  21:30     1   Matchweek 3  Tue  Away      W  2.0  1.0
# 3     2024-08-31  17:00     1   Matchweek 4  Sat  Home      W  7.0  0.0
# 4     2024-09-15  16:15     1   Matchweek 5  Sun  Away      W  4.0  1.0
# ...          ...    ...   ...           ...  ...   ...    ...  ...  ...
# 4313  2020-07-05  17:00     1  Matchweek 34  Sun  Home      L  0.0  1.0
# 4314  2020-07-08  22:00     1  Matchweek 35  Wed  Away      L  0.0  1.0
# 4315  2020-07-12  14:00     1  Matchweek 36  Sun  Home      L  0.0  2.0
# 4316  2020-07-16  21:00     1  Matchweek 37  Thu  Away      L  0.0  1.0
# 4317  2020-07-19  21:00     1  Matchweek 38  Sun  Home      D  0.0  0.0
#
#             opponent  ...              referee  match report    sh   sot  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'opp formation', 'referee', 'match report', 'sh', 'sot', 'dist', 'fk',
#        'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %%
def get_result(row):
    if row['gf'] > row['ga']:
        return 1
    elif row['gf'] < row['ga']:
        return 0
    else:
        return -1
df['result'] = df.apply(get_result, axis = 1)

# %%
feature =[
    'xg',
    'xga',
    'attendance',
    'gf',
    'ga',
    'sh',
    'poss',
    'sot',
    'dist',
    'fk',
    'pkatt'
]

# %%
x= [feature]
y= df['result']

# %%
from sklearn.preprocessing import LabelEncoder
lbl_enco = LabelEncoder()
for col in df.columns:
    if df[col].dtypes == 'object':
        df[col] = lbl_enco.fit_transform(df[col])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in feature:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=df[i], y=df['result'])
    plt.show()

# %%
for col in feature:
    plt.figure(figsize=(8, 2))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
print(df[df['xg'] > 3.5][['xg', 'gf', 'team']])
# Out:
#        xg   gf  team
# 3     4.7  7.0     4
# 5     3.9  5.0     4
# 9     3.8  5.0     4
# 15    5.0  5.0     4
# 20    4.4  7.0     4
# 35    4.4  3.0     3
# 40    4.0  5.0     3
# 57    4.4  4.0    21
# 71    5.9  4.0    21
# 89    4.0  1.0     2
# 100   3.6  3.0     2
# 102   3.8  7.0     2
# 106   3.6  4.0    26
# 571   3.7  2.0     4
# 606   4.5  2.0    11
# 631   4.6  7.0    11
# 643   3.9  3.0     3
# 682   4.6  4.0     2
# 969   4.5  0.0    10
# 1005  4.0  4.0     6
# 1007  3.9  3.0     6
# 1281  4.0  3.0     4
# 1283  3.9  3.0     4
# 1290  4.0  2.0     4
# 1314  3.6  3.0     4
# 1317  3.7  4.0    21
# 1336  4.1  4.0    21
# 1342  4.5  6.0    21
# 1460  3.7  4.0    26
# 1490  4.1  3.0    20
# 1668  3.7  5.0    19
# 2058  3.9  4.0    21
# 2070  4.5  3.0    21
# 2101  4.1  2.0     4
# 2102  3.6  4.0     4
# 2127  3.8  4.0     3
# 2152  3.7  3.0    23
# 2219  4.4  4.0    20
# 2290  4.9  4.0    26
# 2291  4.4  5.0    26
# 2753  3.9  4.0    16
# 2837  3.8  3.0    21
# ...

# %%
for col in feature:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
for col in feature:
    plt.figure(figsize=(8, 2))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[feature], df['result'], test_size=0.2, random_state=42)

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler

# 2. Oversample only training data
ros = RandomOverSampler(random_state=42)
x_train_res, y_train_res = ros.fit_resample(x_train, y_train)

# 3. Scale (fit only on train, transform both)
scaler = StandardScaler()
x_train_res = scaler.fit_transform(x_train_res)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7599364069952306

# %%
from sklearn.ensemble import RandomForestClassifier
model_1 = RandomForestClassifier(n_estimators=1000, random_state=42)
model_1.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=42)

# %%
y_pred_1= model.predict(x_test)
print("Accuracy of Random Forest:", accuracy_score(y_test, y_pred_1))
# Out:
# Accuracy of Random Forest: 0.7599364069952306

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 28  70  81]
#  [  0 223   0]
#  [  0   0 227]]
#               precision    recall  f1-score   support
#
#           -1       1.00      0.16      0.27       179
#            0       0.76      1.00      0.86       223
#            1       0.74      1.00      0.85       227
#
#     accuracy                           0.76       629
#    macro avg       0.83      0.72      0.66       629
# weighted avg       0.82      0.76      0.69       629

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 300, 500],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

grid = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='f1_macro')
grid.fit(x_train_res, y_train_res)
print("Best parameters:", grid.best_params_)

best_rf = grid.best_estimator_
y_pred_rf = best_rf.predict(x_test)
print("Tuned Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# Tuned Random Forest Accuracy: 0.9952305246422893
#               precision    recall  f1-score   support
#
#           -1       0.98      1.00      0.99       179
#            0       1.00      0.99      1.00       223
#            1       1.00      1.00      1.00       227
#
#     accuracy                           1.00       629
#    macro avg       0.99      1.00      0.99       629
# weighted avg       1.00      1.00      1.00       629

# %%
# Use ** to unpack best parameters when creating the model
from sklearn.ensemble import RandomForestClassifier

best_params = grid.best_params_
model = RandomForestClassifier(**best_params, random_state=42)
model.fit(x_train_res, y_train_res)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9952305246422893
# [[179   0   0]
#  [  2 221   0]
#  [  1   0 226]]
#               precision    recall  f1-score   support
#
#           -1       0.98      1.00      0.99       179
#            0       1.00      0.99      1.00       223
#            1       1.00      1.00      1.00       227
#
#     accuracy                           1.00       629
#    macro avg       0.99      1.00      0.99       629
# weighted avg       1.00      1.00      1.00       629
